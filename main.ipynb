# %%
# Import packages
import pandas as pd
import os, sys
import ydata_profiling as yp
import py_entitymatching as em

# %%
# Parameter
PATH_DIR = os.getcwd()
DATASETS_FOLDER = 'datasets'
REPORT_FOLDER = 'reports'
ORIGINAL_REPORT_FOLDER = 'original'
SAMPLED_REPORT_FOLDER = 'sampled'
file1 = 'acmProfiles.csv'
file2 = 'dblpProfiles.csv'
matched = 'dblpAcmIdDuplicates.csv'

# %%
# Define Magellan Pineline
class MagellanPineline:
    def __init__(self, fileNameA, fileNameB, matched, expected) -> None:
        pathdir = PATH_DIR + os.sep + DATASETS_FOLDER
        self.__Acsv__ = pathdir + os.sep + fileNameA
        self.__Bcsv__ = pathdir + os.sep + fileNameB
        self.__Matched__ = pathdir + os.sep + matched
        self.A = pd.DataFrame()
        self.B = pd.DataFrame()
        self.sampleA = pd.DataFrame()
        self.sampleB = pd.DataFrame()
        self.C = pd.DataFrame()
        self.matched = pd.DataFrame()
        self.expected = expected

    def readFile(self):
        self.A = em.read_csv_metadata(self.__Acsv__, key='id')
        self.B = em.read_csv_metadata(self.__Bcsv__, key='id')
#         self.C = em.read_csv_metadata(self.__Matched__)

    def explore_sample(self):
        prtA = yp.ProfileReport(self.A)
        prtA.to_file(PATH_DIR + os.sep + REPORT_FOLDER + os.sep + ORIGINAL_REPORT_FOLDER + os.sep + file1[:-4] + '.html')
        prtB = yp.ProfileReport(self.B)
        prtB.to_file(PATH_DIR + os.sep + REPORT_FOLDER + os.sep + ORIGINAL_REPORT_FOLDER + os.sep + file2[:-4] + '.html')
        
    def down_sampling(self, size, y_param):
        self.sampleA, self.sampleB = em.down_sample(self.A, self.B, size=size, y_param=y_param, show_progress=True)
        
    def block(self):
        ob = em.OverlapBlocker()
        self.C = ob.block_tables(self.sampleA, self.sampleB, 'title', 'title', word_level=True, overlap_size=5, 
                    l_output_attrs=['title', 'year', 'authors','venue'], 
                    r_output_attrs=['title', 'year', 'authors','venue'],
                    show_progress=False)
        return self.C
    
    def labling(self):
        self.matched = em.read_csv_metadata(self.__Matched__, key='id', 
                                            ltable=self.sampleA, rtable=self.sampleB,
                         fk_ltable='entityId1', fk_rtable='entityId2',
                         )
        
        label_dict = {(row['entityId2'], row['entityId1']): row['id'] for _, row in self.matched.iterrows()}
        def get_label(row):
            entityId1 = row['ltable_id']
            entityId2 = row['rtable_id']
            if (entityId1, entityId2) in label_dict:
                return 1
            else:
                return 0
        self.C['label'] = self.C.apply(get_label, axis=1)
        return self.C
    
    def train(self):
        IJ = em.split_train_test(self.C, train_proportion=0.5, random_state=0)
        I = IJ['train']
        J = IJ['test']
        dt = em.DTMatcher(name='DecisionTree', random_state=0)
        svm = em.SVMMatcher(name='SVM', random_state=0)
        rf = em.RFMatcher(name='RF', random_state=0)
        lg = em.LogRegMatcher(name='LogReg', random_state=0)
        ln = em.LinRegMatcher(name='LinReg')
        F = em.get_features_for_matching(self.sampleA, self.sampleB, validate_inferred_attr_types=False)
        F.feature_name

    def execute(self):
        self.readFile()

# %%
problem = MagellanPineline(file1, file2, matched, 0.8)

# %%
problem.readFile()
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.
# Metadata file is not present in the given path; proceeding to read the csv file.

# %%
problem.down_sampling(1000,1)
# Out:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00

# %%
problem.explore_sample()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
problem.sampleA
# Out:
#         id  \
# 0        0
# 2049  2049
# 2        2
# 2048  2048
# 4        4
# ...    ...
# 2041  2041
# 2042  2042
# 2043  2043
# 2046  2046
# 2047  2047
#
#                                                                                               title  \
# 0                                              The WASA2 object-oriented workflow management system
# 2049                                        Composing XSL transformations with XML publishing views
# 2                                      World Wide Database-integrating the Web, CORBA and databases
# 2048                                                 Cache-and-query for wide area sensor databases
# 4                                              The CCUBE constraint object-oriented database system
# ...                                                                                             ...
# 2041                                                Formal semantics and analysis of object queries
# 2042                                                                      A theory of redo recovery
# 2043  A characterization of the sensitivity of query optimization to storage access cost parameters
# 2046                                    Scientific data repositories: designing for a moving target
# 2047                                                      Extracting structured data from Web pages
#
#         year  \
# 0     1999.0
# 2049  2003.0
# 2     1999.0
# 2048  2003.0
# 4     1999.0
# ...      ...
# 2041  2003.0
# 2042  2003.0
# 2043  2003.0
# 2046  2003.0
# 2047  2003.0
#
#                                                                                             authors  \
# 0                                                                   Gottfried Vossen, Mathias Weske
# 2049                                                 Chengkai Li, Philip Bohannon, P. P. S. Narayan
# 2     Athman Bouguettaya, Boualem Benatallah, Lily Hendra, James Beard, Kevin Smith, Mourad Quzzani
# 2048                              Amol Deshpande, Suman Nath, Phillip B. Gibbons, Srinivasan Seshan
# 4                               Alexander Brodsky, Victor E. Segal, Jia Chen, Paval A. Exarkhopoulo
# ...                                                                                             ...
# 2041                                                                                  G. M. Bierman
# 2042                                                                       David Lomet, Mark Tuttle
# 2043                                                              Frederick R. Reiss, Tapas Kanungo
# 2046                               Etzard Stolte, Christoph von Praun, Gustavo Alonso, Thomas Gross
# 2047                                        Arvind Arasu, Hector Garcia-Molina, Stanford University
#
#                                                venue  entityUrl
# 0     International Conference on Management of Data     304586
# 2049  International Conference on Management of Data     872820
# 2     International Conference on Management of Data     304589
# 2048  International Conference on Management of Data     872818
# 4     International Conference on Management of Data     304582
# ...                                              ...        ...
# 2041  International Conference on Management of Data     872807
# 2042  International Conference on Management of Data     872806
# 2043  International Conference on Management of Data     872804
# 2046  International Conference on Management of Data     872800
# 2047  International Conference on Management of Data     872799
#
# [919 rows x 6 columns]

# %%
problem.sampleB
# Out:
#         id              venue  year  \
# 2221  2221  SIGMOD Conference  1996
# 1536  1536               VLDB  2000
# 1214  1214  SIGMOD Conference  1995
# 961    961               VLDB  1998
# 2357  2357  SIGMOD Conference  1998
# ...    ...                ...   ...
# 792    792  SIGMOD Conference  2000
# 844    844               VLDB  1998
# 1571  1571      SIGMOD Record  1999
# 678    678  SIGMOD Conference  1994
# 1548  1548               VLDB  1994
#
#                                                                         authors  \
# 2221                    Donald Kossmann, Michael J. Franklin, Bj�rn ��r J�nsson
# 1536                                                           Michael J. Carey
# 1214                                         Nelson Mendon�a Mattos, Jim Melton
# 961                                          Mitch Cherniack, Stanley B. Zdonik
# 2357      V. S. Subrahmanian, Sibel Adali, Maria Luisa Sapino, Piero A. Bonatti
# ...                                                                         ...
# 792                                           Junghoo Cho, Hector Garcia-Molina
# 844   Simonas Saltenis, Christian S. Jensen, Giedrius Slivinskas, Rasa Bliujute
# 1571                                        Klaus R. Dittrich, Ruxandra Domenig
# 678                                                               Michael Ubell
# 1548                                                        Ralf Hartmut G�ting
#
#                                                                                                     title  \
# 2221                                             Performance Tradeoffs for Client-Server Query Processing
# 1536  Toto, We're Not in Kansas Anymore: On Transitioning from Research to the Real (Invited Industria...
# 1214                                 An Overview of the Emerging Third-Generation SQL Standard (Tutorial)
# 961                                                      Inferring Function Semantics to Optimize Queries
# 2357                                                                           A Multi-Similarity Algebra
# ...                                                                                                   ...
# 792                                                         Synchronizing a Database to Improve Freshness
# 844                                                 R-Tree Based Indexing of Now-Relative Bitemporal Data
# 1571                                             An Overview and Classification of Mediated Query Systems
# 678                                                          The Montage Extensible DataBlade Achitecture
# 1548                                                   GraphDB: Modeling and Querying Graphs in Databases
#
#                        entityUrl
# 2221    conf/sigmod/FranklinJK96
# 1536           conf/vldb/Carey00
# 1214       conf/sigmod/MattosM95
# 961       conf/vldb/CherniackZ98
# 2357      conf/sigmod/AdaliBSS98
# ...                          ...
# 792           conf/sigmod/ChoG00
# 844      conf/vldb/BliujuteJSS98
# 1571  journals/sigmod/DomenigD99
# 678          conf/sigmod/Ubell94
# 1548          conf/vldb/Guting94
#
# [1000 rows x 6 columns]

# %%
problem.block()
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\py_stringsimjoin\utils\generic_helper.py:76: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   projected_dataframe = dataframe[proj_attrs].dropna(0,
# C:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\py_stringsimjoin\utils\generic_helper.py:76: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   projected_dataframe = dataframe[proj_attrs].dropna(0,
#      _id  ltable_id  rtable_id  \
# 0      0        390       1697
# 1      1       1739       1095
# 2      2       1516       1910
# 3      3        902        427
# 4      4       1318       1738
# ..   ...        ...        ...
# 991  991          3        463
# 992  992        237        764
# 993  993        811       1187
# 994  994        937       1162
# 995  995       1977       1017
#
#                                                                        ltable_title  \
# 0                       Designing an ultra highly available DBMS (tutorial session)
# 1                                                  Energy efficient indexing on air
# 2                                   Adapting materialized views after redefinitions
# 3                         A graphical query language for mobile information systems
# 4                                    VXMLR: A Visual XML-Relational Database System
# ..                                                                              ...
# 991                                        XML-based information mediation with MIX
# 992                                 Enhanced nearest neighbour search on the R-tree
# 993  Relational Databases for Querying XML Documents: Limitations and Opportunities
# 994         Don't Scrap It, Wrap It! A Wrapper Architecture for Legacy Data Sources
# 995                        Safe and efficient sharing of persistent objects in Thor
#
#      ltable_year  \
# 0         2000.0
# 1         1994.0
# 2         1995.0
# 3         2003.0
# 4         2001.0
# ..           ...
# 991       1999.0
# 992       1998.0
# 993       1999.0
# 994       1997.0
# 995       1996.0
#
#                                                                                           ltable_authors  \
# 0                                                    Svein Erik Bratsberg, &#216;ystein Torbj&#248;rnsen
# 1                                                     Tomasz Imielinski, S. Viswanathan, B. R. Badrinath
# 2                                                      Ashish Gupta, Inderpal S. Mumick, Kenneth A. Ross
# 3                                                                                           Ya-Hui Chang
# 4                Aoying Zhou, Hongjun Lu, Shihui Zheng, Yuqi Liang, Long Zhang, Wenyun Ji, Zengping Tian
# ..                                                                                                   ...
# 991  Chaitan Baru, Amarnath Gupta, Bertram Lud&#228;scher, Richard Marciano, Yannis Papakonstantinou,...
# 992                                                                     King Lum Cheung, Ada Wai-Chee Fu
# 993   Jayavel Shanmugasundaram, Kristin Tufte, Chun Zhang, Gang He, David J. DeWitt, Jeffrey F. Naughton
# 994                                                                     Mary Tork Roth, Peter M. Schwarz
# 995  B. Liskov, A. Adya, M. Castro, S. Ghemawat, R. Gruber, U. Maheshwari, A. C. Myers, M. Day, L. Sh...
#
#                                        ltable_venue  \
# 0    International Conference on Management of Data
# 1    International Conference on Management of Data
# 2    International Conference on Management of Data
# 3                                 ACM SIGMOD Record
# 4                             Very Large Data Bases
# ..                                              ...
# 991  International Conference on Management of Data
# 992                               ACM SIGMOD Record
# 993                           Very Large Data Bases
# 994                           Very Large Data Bases
# 995  International Conference on Management of Data
#
#                                                                        rtable_title  \
# 0                                Tutorial: Designing an Ultra Highly Available DBMS
# 1                                                  Energy Efficient Indexing on Air
# 2                                   Adapting Materialized Views after Redefinitions
# 3                         A Graphical Query Language for Mobile Information Systems
# 4                                    VXMLR: A Visual XML-Relational Database System
# ..                                                                              ...
# 991                                        XML-Based Information Mediation with MIX
# 992                                 Enhanced Nearest Neighbour Search on the R-tree
# 993  Relational Databases for Querying XML Documents: Limitations and Opportunities
# 994         Don't Scrap It, Wrap It! A Wrapper Architecture for Legacy Data Sources
# 995                        Safe and Efficient Sharing of Persistent Objects in Thor
#
#      rtable_year  \
# 0           2000
# 1           1994
# 2           1995
# 3           2003
# 4           2001
# ..           ...
# 991         1999
# 992         1998
# 993         1999
# 994         1997
# 995         1996
#
#                                                                                           rtable_authors  \
# 0                                                              �ystein Torbj�rnsen, Svein Erik Bratsberg
# 1                                                     S. Viswanathan, B. R. Badrinath, Tomasz Imielinski
# 2                                                   Ashish Gupta, Inderpal Singh Mumick, Kenneth A. Ross
# 3                                                                                           Ya-Hui Chang
# 4                Aoying Zhou, Wenyun Ji, Shihui Zheng, Hongjun Lu, Yuqi Liang, Zengping Tian, Long Zhang
# ..                                                                                                   ...
# 991  Yannis Papakonstantinou, Richard Marciano, Chaitanya K. Baru, Pavel Velikhov, Vincent Chu, Amarn...
# 992                                                                     Ada Wai-Chee Fu, King Lum Cheung
# 993   Jeffrey F. Naughton, Kristin Tufte, Chun Zhang, Gang He, David J. DeWitt, Jayavel Shanmugasundaram
# 994                                                                     Peter M. Schwarz, Mary Tork Roth
# 995  Atul Adya, Liuba Shrira, Miguel Castro, Robert Gruber, Andrew C. Myers, Barbara Liskov, Umesh Ma...
#
#           rtable_venue
# 0    SIGMOD Conference
# 1    SIGMOD Conference
# 2    SIGMOD Conference
# 3        SIGMOD Record
# 4                 VLDB
# ..                 ...
# 991  SIGMOD Conference
# 992      SIGMOD Record
# 993               VLDB
# 994               VLDB
# 995  SIGMOD Conference
#
# [996 rows x 11 columns]

# %%
problem.labling()
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.
#      _id  ltable_id  rtable_id  \
# 0      0        390       1697
# 1      1       1739       1095
# 2      2       1516       1910
# 3      3        902        427
# 4      4       1318       1738
# ..   ...        ...        ...
# 991  991          3        463
# 992  992        237        764
# 993  993        811       1187
# 994  994        937       1162
# 995  995       1977       1017
#
#                                                                        ltable_title  \
# 0                       Designing an ultra highly available DBMS (tutorial session)
# 1                                                  Energy efficient indexing on air
# 2                                   Adapting materialized views after redefinitions
# 3                         A graphical query language for mobile information systems
# 4                                    VXMLR: A Visual XML-Relational Database System
# ..                                                                              ...
# 991                                        XML-based information mediation with MIX
# 992                                 Enhanced nearest neighbour search on the R-tree
# 993  Relational Databases for Querying XML Documents: Limitations and Opportunities
# 994         Don't Scrap It, Wrap It! A Wrapper Architecture for Legacy Data Sources
# 995                        Safe and efficient sharing of persistent objects in Thor
#
#      ltable_year  \
# 0         2000.0
# 1         1994.0
# 2         1995.0
# 3         2003.0
# 4         2001.0
# ..           ...
# 991       1999.0
# 992       1998.0
# 993       1999.0
# 994       1997.0
# 995       1996.0
#
#                                                                                           ltable_authors  \
# 0                                                    Svein Erik Bratsberg, &#216;ystein Torbj&#248;rnsen
# 1                                                     Tomasz Imielinski, S. Viswanathan, B. R. Badrinath
# 2                                                      Ashish Gupta, Inderpal S. Mumick, Kenneth A. Ross
# 3                                                                                           Ya-Hui Chang
# 4                Aoying Zhou, Hongjun Lu, Shihui Zheng, Yuqi Liang, Long Zhang, Wenyun Ji, Zengping Tian
# ..                                                                                                   ...
# 991  Chaitan Baru, Amarnath Gupta, Bertram Lud&#228;scher, Richard Marciano, Yannis Papakonstantinou,...
# 992                                                                     King Lum Cheung, Ada Wai-Chee Fu
# 993   Jayavel Shanmugasundaram, Kristin Tufte, Chun Zhang, Gang He, David J. DeWitt, Jeffrey F. Naughton
# 994                                                                     Mary Tork Roth, Peter M. Schwarz
# 995  B. Liskov, A. Adya, M. Castro, S. Ghemawat, R. Gruber, U. Maheshwari, A. C. Myers, M. Day, L. Sh...
#
#                                        ltable_venue  \
# 0    International Conference on Management of Data
# 1    International Conference on Management of Data
# 2    International Conference on Management of Data
# 3                                 ACM SIGMOD Record
# 4                             Very Large Data Bases
# ..                                              ...
# 991  International Conference on Management of Data
# 992                               ACM SIGMOD Record
# 993                           Very Large Data Bases
# 994                           Very Large Data Bases
# 995  International Conference on Management of Data
#
#                                                                        rtable_title  \
# 0                                Tutorial: Designing an Ultra Highly Available DBMS
# 1                                                  Energy Efficient Indexing on Air
# 2                                   Adapting Materialized Views after Redefinitions
# 3                         A Graphical Query Language for Mobile Information Systems
# 4                                    VXMLR: A Visual XML-Relational Database System
# ..                                                                              ...
# 991                                        XML-Based Information Mediation with MIX
# 992                                 Enhanced Nearest Neighbour Search on the R-tree
# 993  Relational Databases for Querying XML Documents: Limitations and Opportunities
# 994         Don't Scrap It, Wrap It! A Wrapper Architecture for Legacy Data Sources
# 995                        Safe and Efficient Sharing of Persistent Objects in Thor
#
#      rtable_year  \
# 0           2000
# 1           1994
# 2           1995
# 3           2003
# 4           2001
# ..           ...
# 991         1999
# 992         1998
# 993         1999
# 994         1997
# 995         1996
#
#                                                                                           rtable_authors  \
# 0                                                              �ystein Torbj�rnsen, Svein Erik Bratsberg
# 1                                                     S. Viswanathan, B. R. Badrinath, Tomasz Imielinski
# 2                                                   Ashish Gupta, Inderpal Singh Mumick, Kenneth A. Ross
# 3                                                                                           Ya-Hui Chang
# 4                Aoying Zhou, Wenyun Ji, Shihui Zheng, Hongjun Lu, Yuqi Liang, Zengping Tian, Long Zhang
# ..                                                                                                   ...
# 991  Yannis Papakonstantinou, Richard Marciano, Chaitanya K. Baru, Pavel Velikhov, Vincent Chu, Amarn...
# 992                                                                     Ada Wai-Chee Fu, King Lum Cheung
# 993   Jeffrey F. Naughton, Kristin Tufte, Chun Zhang, Gang He, David J. DeWitt, Jayavel Shanmugasundaram
# 994                                                                     Peter M. Schwarz, Mary Tork Roth
# 995  Atul Adya, Liuba Shrira, Miguel Castro, Robert Gruber, Andrew C. Myers, Barbara Liskov, Umesh Ma...
#
#           rtable_venue  label
# 0    SIGMOD Conference      1
# 1    SIGMOD Conference      1
# 2    SIGMOD Conference      1
# 3        SIGMOD Record      1
# 4                 VLDB      1
# ..                 ...    ...
# 991  SIGMOD Conference      1
# 992      SIGMOD Record      1
# 993               VLDB      1
# 994               VLDB      1
# 995  SIGMOD Conference      1
#
# [996 rows x 12 columns]

# %%
IJ = em.split_train_test(problem.C, train_proportion=0.5, random_state=0)
I = IJ['train']
J = IJ['test']
dt = em.DTMatcher(name='DecisionTree', random_state=0)
svm = em.SVMMatcher(name='SVM', random_state=0)
rf = em.RFMatcher(name='RF', random_state=0)
lg = em.LogRegMatcher(name='LogReg', random_state=0)
ln = em.LinRegMatcher(name='LinReg')
F = em.get_features_for_matching(problem.sampleA, problem.sampleB, validate_inferred_attr_types=False)
H = em.extract_feature_vecs(I, 
                            feature_table=F, 
                            attrs_after='label',
                            show_progress=False)

# %%
F.feature_name
# Out:
# 0                               id_id_exm
# 1                               id_id_anm
# 2                          id_id_lev_dist
# 3                           id_id_lev_sim
# 4             title_title_jac_qgm_3_qgm_3
# 5         title_title_cos_dlm_dc0_dlm_dc0
# 6                         title_title_mel
# 7                    title_title_lev_dist
# 8                     title_title_lev_sim
# 9                           year_year_exm
# 10                          year_year_anm
# 11                     year_year_lev_dist
# 12                      year_year_lev_sim
# 13        authors_authors_jac_qgm_3_qgm_3
# 14    authors_authors_cos_dlm_dc0_dlm_dc0
# 15                    authors_authors_mel
# 16               authors_authors_lev_dist
# 17                authors_authors_lev_sim
# Name: feature_name, dtype: object

# %%
H.head()
# Out:
#      _id  ltable_id  rtable_id  id_id_exm  id_id_anm  id_id_lev_dist  \
# 958  958       1527       2270          0   0.672687               3
# 401  401       1156        854          0   0.738754               3
# 799  799       2152        372          0   0.172862               3
# 654  654       2083        916          0   0.439750               4
# 441  441       2058        199          0   0.096696               4
#
#      id_id_lev_sim  title_title_jac_qgm_3_qgm_3  \
# 958           0.25                     0.564516
# 401           0.25                     0.506849
# 799           0.25                     0.428571
# 654           0.00                     0.586207
# 441           0.00                     0.222222
#
#      title_title_cos_dlm_dc0_dlm_dc0  title_title_mel  ...  year_year_exm  \
# 958                         0.285714         0.886018  ...            1.0
# 401                         0.250000         0.903653  ...            1.0
# 799                         0.629941         0.701343  ...            0.0
# 654                         0.200000         0.898636  ...            1.0
# 441                         0.555556         0.697577  ...            0.0
#
#      year_year_anm  year_year_lev_dist  year_year_lev_sim  \
# 958       1.000000                 2.0           0.666667
# 401       1.000000                 2.0           0.666667
# 799       0.998003                 6.0           0.000000
# 654       1.000000                 2.0           0.666667
# 441       0.999501                 3.0           0.500000
#
#      authors_authors_jac_qgm_3_qgm_3  authors_authors_cos_dlm_dc0_dlm_dc0  \
# 958                         0.636364                             0.600000
# 401                         1.000000                             1.000000
# 799                         0.007752                             0.000000
# 654                         0.811594                             0.617213
# 441                         0.000000                             0.000000
#
#      authors_authors_mel  authors_authors_lev_dist  authors_authors_lev_sim  \
# 958             0.766013                      26.0                 0.235294
# 401             1.000000                       0.0                 1.000000
# 799             0.487677                     106.0                 0.086207
# 654             0.841587                      47.0                 0.241935
# 441             0.474221                      70.0                 0.113924
#
#      label
# 958      1
# 401      1
# 799      0
# 654      1
# 441      0
#
# [5 rows x 22 columns]

# %%
any(pd.notnull(H))
# Out:
# True

# %%
H = em.impute_table(H, 
                exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'label'],
                strategy='mean')
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\py_entitymatching\matcher\matcherutils.py:224: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   imp.statistics_[pd.np.isnan(imp.statistics_)] = val_all_nans

# %%
result = em.select_matcher([dt, rf, svm, ln, lg], table=H, 
        exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'label'],
        k=5,
        target_attr='label', metric_to_select_matcher='f1', random_state=0)
result['cv_stats']
# Out:
#         Matcher  Average precision  Average recall  Average f1
# 0  DecisionTree           0.971724        0.972589    0.971994
# 1            RF           0.977804        0.991342    0.984422
# 2           SVM           0.945944        0.975186    0.960146
# 3        LinReg           0.957269        1.000000    0.978099
# 4        LogReg           0.970279        0.993939    0.981842

# %%
dt = em.DTMatcher(name='DecisionTree', random_state=0)
dt.fit(table=H, 
       exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'label'], 
       target_attr='label')

# Convert J into a set of feature vectors using F
L = em.extract_feature_vecs(J, feature_table=F,
                            attrs_after='label', show_progress=False)

L = em.impute_table(L, 
                exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'label'],
                strategy='mean')
# Predict on L 
predictions = dt.predict(table=L, exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'label'], 
              append=True, target_attr='predicted', inplace=False, return_probs=True, show_progress=True,
                        probs_attr='proba')
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\py_entitymatching\matcher\matcherutils.py:224: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   imp.statistics_[pd.np.isnan(imp.statistics_)] = val_all_nans
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 14
#      10 L = em.impute_table(L,
#      11                 exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'label'],
#      12                 strategy='mean')
#      13 # Predict on L
# ---> 14 predictions = dt.predict(table=L, exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'label'],
#      15               append=True, target_attr='predicted', inplace=False, return_probs=True, show_progress=True,
#      16                         probs_attr='proba')
#
# TypeError: MLMatcher.predict() got an unexpected keyword argument 'show_progress'
